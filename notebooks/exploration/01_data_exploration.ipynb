# %% [markdown]
# # Data Exploration
#
# This notebook is for exploring the dataset statistics and visualizing samples.

# %%
import sys
sys.path.insert(0, '../..')

import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from pathlib import Path
from src.utils.config import DataConfig

# %matplotlib inline

# %%
# Load configuration
config = DataConfig()
print(f"Data directory: {config.input_dir}")
